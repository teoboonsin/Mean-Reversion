# %%
def apply_factor(product1,product2):
    z=1
    y=1

    if product1=='RB' and product2 =='RB':
        z=42
        y=42
    elif product1=='HO' and product2 =='HO':
        z=42
        y=42
    elif product1=='RB' and product2 =='HO':
        z=42
        y=42
    elif product1=='HO' and product2 =='RB':
        z=42
        y=42
    elif product1=='HO' and product2 =='CL':
        z=42
        y=1  
    elif product1=='RB' and product2 =='CL':
        z=42
        y=1          
    elif product1=='CL' and product2 =='B':
        z=1
        y=1       
    elif product1=='G' and product2 =='G':
        z=(1/7.45)
        y=(1/7.45)
    elif product1=='G' and product2 =='B':
        z=(1/7.45)
    elif product1=="HO" and product2=='G':
        z=42
        y=(1/7.45)
    
    else:
        pass

    return z,y




class Mth_1(object):
    
    def __init__(self):
        pass
        
    def pdt_type1(self):
        
        product=''
        while True:
            inst=int(raw_input('Please input the number of the product you want to see the seasonals: 1) Brent 2) Gasoil 3) HO 4) RBOB 5) WTI: '))
    
            if inst==1:
                product='B'
                break
            elif inst==2:
                product='G'
                break   
            elif inst==3:
                product='HO'
                break      
            elif inst==4:
                product='RB'
                break       
            elif inst==5:
                product='CL'
                break       
            else:
                print 'You did not input a correct number. Please try again.'
        
        return product
    
    def mth_no1(self):
        month=''
        while True:
            Mth=int(raw_input('Please input the month of the contract which you wish to evaluate in numbers from 1-12: '))
    
            if Mth==1:
                month='Jan'
                break
            elif Mth==2:
                month='Feb'
                break   
            elif Mth==3:
                month='Mar'
                break   
            elif Mth==4:
                month='Apr'
                break   
            elif Mth==5:
                month='May'
                break          
            elif Mth==6:
                month='Jun'
                break   
            elif Mth==7:
                month='Jul'
                break   
            elif Mth==8:
                month='Aug'
                break   
            elif Mth==9:
                month='Sep'
                break   
            elif Mth==10:
                month='Oct'
                break   
            elif Mth==11:
                month='Nov'
                break   
            elif Mth==12:
                month='Dec'
                break 
            else:
                print 'You did not input a correct number. Please try again.'
        
        return month      

    
class Mth_2(object):
    
    def __init__(self):
        pass
        
    def pdt_type2(self):
        
        product=''
        while True:
            inst=int(raw_input('Please input the number of the product you want to see the seasonals: 1) Brent 2) Gasoil 3) HO 4) RBOB 5) WTI: '))
    
            if inst==1:
                product='B'
                break
            elif inst==2:
                product='G'
                break   
            elif inst==3:
                product='HO'
                break      
            elif inst==4:
                product='RB'
                break       
            elif inst==5:
                product='CL'
                break       
            else:
                print 'You did not input a correct number. Please try again.'
        
        return product
        
    
    def mth_no2(self):
        month=''
        while True:
            Mth=int(raw_input('Please input the month of the contract which you wish to evaluate in numbers from 1-12: '))
    
            if Mth==1:
                month='Jan'
                break
            elif Mth==2:
                month='Feb'
                break   
            elif Mth==3:
                month='Mar'
                break   
            elif Mth==4:
                month='Apr'
                break   
            elif Mth==5:
                month='May'
                break          
            elif Mth==6:
                month='Jun'
                break   
            elif Mth==7:
                month='Jul'
                break   
            elif Mth==8:
                month='Aug'
                break   
            elif Mth==9:
                month='Sep'
                break   
            elif Mth==10:
                month='Oct'
                break   
            elif Mth==11:
                month='Nov'
                break   
            elif Mth==12:
                month='Dec'
                break 
            else:
                print 'You did not input a correct number. Please try again.'
        
        return month

# %%
import numpy as np
import pandas as pd
import os
import statsmodels.tsa.stattools as ts
import statsmodels.api as sm
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
### user specify instrument and contract month

product1=''
month1=''
product2=''
month2=''

front_mth=Mth_1()
product1 = front_mth.pdt_type1()
month1=front_mth.mth_no1()
#seasonal_year1=str(raw_input('Please specify the contract year: '))

back_mth=Mth_2()
product2=back_mth.pdt_type2()
month2=back_mth.mth_no2()
#seasonal_year2=str(raw_input('Please specify the contract year: '))

#user specify period
start_mth=raw_input('Please input start mth of seasonal period in MM format: ')
start_day=raw_input('Please input start day of seasonal period in DD format: ')
i=int(raw_input('Please input integers -1,0,or +1 to add on to current year for start date year: '))
            
end_mth=raw_input('Please input end mth of seasonal period in MM format: ')
end_day=raw_input('Please input end day of seasonal period in DD format: ')
            
j=int(raw_input('Please input integers -1,0, or +1 to add on to current year for end date year: '))
# Out:
# Please input the number of the product you want to see the seasonals: 1) Brent 2) Gasoil 3) HO 4) RBOB 5) WTI: 5
# Please input the month of the contract which you wish to evaluate in numbers from 1-12: 9
# Please input the number of the product you want to see the seasonals: 1) Brent 2) Gasoil 3) HO 4) RBOB 5) WTI: 1
# Please input the month of the contract which you wish to evaluate in numbers from 1-12: 9
# Please input start mth of seasonal period in MM format: 01
# Please input start day of seasonal period in DD format: 01
# Please input integers -1,0,or +1 to add on to current year for start date year: 0
# Please input end mth of seasonal period in MM format: 06
# Please input end day of seasonal period in DD format: 25
# Please input integers -1,0, or +1 to add on to current year for end date year: 0

# %%
start_year=int(raw_input('Please input the start year of contract year: '))
end_year=int(raw_input('Please input the end year of contract year: '))

#input lookback period
lookback=int(raw_input('Please input the lookback period: '))

#creating entry and exit signals
z_score_entry=float(raw_input('Please input the z score for trade entry as a positive float number: '))
z_score_exit=float(raw_input('Please input the z score for trade exit as a positive float number: '))

adf_store=pd.DataFrame(index=np.arange(start_year,end_year+1),columns=np.arange(0,1))
adf_store=adf_store.rename(columns={0:'adf'})

final_pnl_store=pd.DataFrame(index=np.arange(start_year,end_year+1),columns=np.arange(0,1))
final_pnl_store=final_pnl_store.rename(columns={0:'final_pnl'})

hedge_ratio_store=pd.DataFrame(index=np.arange(start_year,end_year+1),columns=np.arange(0,1))
hedge_ratio_store=hedge_ratio_store.rename(columns={0:'hedge_ratio'})
                               
final_pnl_hr_store=pd.DataFrame(index=np.arange(start_year,end_year+1),columns=np.arange(0,1))
final_pnl_hr_store=final_pnl_hr_store.rename(columns={0:'final_pnl_hr'})

min_pnl_store=pd.DataFrame(index=np.arange(start_year,end_year+1),columns=np.arange(0,1))
min_pnl_store=min_pnl_store.rename(columns={0:'min_pnl'})


a=0

while a<=end_year-start_year:
    # %cd Quandl
    # %cd $product1        
    # %cd $month1  
    
    
    #read files - #front month

    path = os.getcwd()
    listing = os.listdir(path)

    month=month1+" "+str(start_year+a)+".xls"
    
    temp = pd.DataFrame()
    temp1=pd.DataFrame()
        
    for infile in listing:
        if infile==month:
            temp=pd.read_excel(infile)
        else:
            pass

    start_date=str(start_year+a+i)+'-'+start_mth+'-'+start_day # create start date 
    end_date=str(start_year+a+j)+'-'+end_mth+'-'+end_day # create end date 

    #Join a date series and temp together

    dates=pd.date_range(start_date, end_date) # range of dates for date axis
    dates=dates.strftime('%Y-%m-%d') #make sure no left out dates
    sample_data=np.arange(0,len(dates)) #just sample numbers to create dataframe

    dates_dataframe=pd.DataFrame({'Date':dates,'data':sample_data}) # create dates dataframe
    dates_dataframe=dates_dataframe.set_index('Date') # set index as Date to facilitate joining

    temp=temp.set_index('Date') # set index as Date to facilitate joining via dates
    temp=dates_dataframe.join(temp) # join dataframes together on Date

    #filter dates by the start and end date
    temp.reset_index(inplace=True)
    
    temp=temp[temp['Date']>=start_date] # filter for start date

    temp=temp[temp['Date']<=end_date] # filter for end date

    temp['Date']=pd.to_datetime(temp['Date']).dt.strftime('%m/%d') # putting date in mm/dd form
    temp=temp.set_index('Date') # putting date back as index

    temp=pd.DataFrame(temp['Settle'],columns=['Settle']) # setting dataframe with date and settle only
    temp=temp.rename(index=str,columns={"Settle":"Front_Month_Settle"})
    
    # %cd ..
    # %cd ..
    # %cd ..
    
    # %cd Quandl
    # %cd $product2
    # %cd $month2
    
    
    #read files - #back month

    path = os.getcwd()
    listing = os.listdir(path)

    month=month1+" "+str(start_year+a)+".xls"

    for infile in listing:
        if infile==month:
            temp1=pd.read_excel(infile)
        else:
            pass

    start_date=str(start_year+a+i)+'-'+start_mth+'-'+start_day # create start date # assume same year
    end_date=str(start_year+a+j)+'-'+end_mth+'-'+end_day # create end date # assume same year


    #Join a date dataframe and the temp dataframe together
            
    dates=pd.date_range(start_date, end_date) # range of dates for date axis
    dates=dates.strftime('%Y-%m-%d') #make sure no left out dates
    sample_data=np.arange(0,len(dates)) #just sample numbers to create dataframe
    
    dates_dataframe=pd.DataFrame({'Date':dates,'data':sample_data}) # create dates dataframe
    dates_dataframe=dates_dataframe.set_index('Date') # set index as Date to facilitate joining
    
    temp1=temp1.set_index('Date') # set index as Date to facilitate joining

    temp1=dates_dataframe.join(temp1) # join dataframes together on Date

    #filter dates by the start and end date
    temp1.reset_index(inplace=True)
    
    temp1=temp1[temp1['Date']>=start_date] # filter for start date

    temp1=temp1[temp1['Date']<=end_date] # filter for end date

    temp1['Date']=pd.to_datetime(temp1['Date']).dt.strftime('%m/%d') # putting date in mm/dd form
    temp1=temp1.set_index('Date') # putting date back as index
    temp1=pd.DataFrame(temp1['Settle'],columns=['Settle'])
    temp1=temp1.rename(index=str,columns={"Settle":"Back_Month_Settle"})

    #join front month and back month

    temp=temp.join(temp1)
    
    # %cd ..
    # %cd ..
    # %cd ..
  
    #drop rows with all NAs
    temp.dropna(axis=0,how='any',inplace=True) # drop rows with all NAs
    
    zf=apply_factor(product1,product2)
    
    #adf calculation
    temp['Spread']=temp['Front_Month_Settle']*zf[0]-temp['Back_Month_Settle']*zf[1]
    adf=float(ts.adfuller(temp['Spread'])[0])  
    
    ##adf store
    adf_store.loc[start_year+a]=adf
    
    #creating MA and STD and z_score
    temp['MA']=pd.rolling_mean(temp['Spread'],lookback)
    temp['M_STD']=pd.rolling_std(temp['Spread'],lookback)  
    temp['z_score']=(temp['Spread']-temp['MA'])/temp['M_STD']

    #creating positions
    temp['long_entry']=temp['z_score'] <= -z_score_entry
    temp['long_exit']=temp['z_score']>=-z_score_exit
    temp['short_entry']=temp['z_score']>=z_score_entry
    temp['short_exit']=temp['z_score']<=z_score_exit
    
    temp['long_entry'][temp['long_entry']==True]=2
    temp['long_exit'][temp['long_exit']==True]=-1

    temp['short_entry'][temp['short_entry']==True]=-2
    temp['short_exit'][temp['short_exit']==True]=1

    temp['long_positions']=temp['long_entry']+temp['long_exit']

    temp['long_positions'][temp['long_positions']==0]=np.nan
    temp['long_positions'][temp['long_positions']==-1]=0
    temp['long_positions'][temp['long_positions']==2]=1
    temp['long_positions']=temp['long_positions'].fillna(method='ffill')

    temp['short_positions']=temp['short_entry']+temp['short_exit']
    temp['short_positions'][temp['short_positions']==0]=np.nan
    temp['short_positions'][temp['short_positions']==1]=0
    temp['short_positions'][temp['short_positions']==-2]=-1
    temp['short_positions']=temp['short_positions'].fillna(method='ffill')
                            
    temp['positions']=temp['long_positions']+temp['short_positions']  
    
    
    #hedge ratio calculation
    model=sm.OLS(temp['Front_Month_Settle']*zf[0], temp['Back_Month_Settle']*zf[1])
    model=model.fit()
    hedge_ratio=model.params[0]
    
    
    #hedge ratio store
    hedge_ratio_store.loc[start_year+a]=hedge_ratio
    
    #pnl calculation
    temp['pnl']=temp['positions'].shift(1)*(temp['Spread']-temp['Spread'].shift(1))*1000
    temp['cumpnl']=temp['pnl'].cumsum()
    final_pnl=temp['cumpnl'].tail(1)[0]
    
    #final pnl store
    
    final_pnl_store.loc[start_year+a]=final_pnl
     
    #min pnl calculation
    min_pnl=temp['cumpnl'].min()
        
    #min_pnl store
    min_pnl_store.loc[start_year+a]=min_pnl
        
    #using hedge ratio
    temp['Spread_hr']=temp['Front_Month_Settle']*zf[0]-hedge_ratio*temp['Back_Month_Settle']*zf[1]

    adf_hr=float(ts.adfuller(temp['Spread_hr'])[0])
    temp['pnl_hr']=temp['positions'].shift(1)*(temp['Spread_hr']-temp['Spread_hr'].shift(1))*1000
    temp['cumpnl_hr']=temp['pnl_hr'].cumsum()
    final_pnl_hr=temp['cumpnl_hr'].tail(1)[0]
    
    final_pnl_hr_store.loc[start_year+a]=final_pnl_hr
    
    a+=1
# Out:
# Please input the start year of contract year: 1996
# Please input the end year of contract year: 2018
# Please input the lookback period: 20
# Please input the z score for trade entry as a positive float number: 2.1
# Please input the z score for trade exit as a positive float number: 1
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl\CL\Sep
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl\B\Sep
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:151: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=20,center=False).mean()
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:152: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=20,center=False).std()
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:161: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:162: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:164: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:165: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl\CL\Sep
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl\B\Sep
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl\CL\Sep
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl\B\Sep
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl\CL\Sep
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl\B\Sep
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl\CL\Sep
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl\B\Sep
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl\CL\Sep
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl\B\Sep
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl\CL\Sep
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl\B\Sep
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl\CL\Sep
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl\B\Sep
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:169: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:171: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:175: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:176: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:177: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl\CL\Sep
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl\B\Sep
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl\CL\Sep
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl\B\Sep
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl\CL\Sep
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl\B\Sep
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl\CL\Sep
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl\B\Sep
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl\CL\Sep
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl\B\Sep
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl\CL\Sep
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl\B\Sep
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl\CL\Sep
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl\B\Sep
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl\CL\Sep
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl\B\Sep
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl\CL\Sep
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl\B\Sep
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl\CL\Sep
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl\B\Sep
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl\CL\Sep
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl\B\Sep
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl\CL\Sep
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl\B\Sep
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl\CL\Sep
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl\B\Sep
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl\CL\Sep
# C:\Users\boonsin.teo\Documents\Quandl\CL
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl\B\Sep
# C:\Users\boonsin.teo\Documents\Quandl\B
# C:\Users\boonsin.teo\Documents\Quandl
# C:\Users\boonsin.teo\Documents

# %%
adf_store
# Out:
#            adf
# 1996  -2.41869
# 1997  -2.52987
# 1998 -0.257957
# 1999  -1.74804
# 2000  -4.44526
# 2001   -1.5153
# 2002  -3.79169
# 2003  -1.71129
# 2004   -1.9198
# 2005  -1.72001
# 2006  -2.17961
# 2007 -0.664489
# 2008  -2.86645
# 2009  -2.59295
# 2010  -1.76394
# 2011  -1.54488
# 2012  -2.79518
# 2013 -0.200776
# 2014   -1.5938
# 2015  -1.40511
# 2016  -1.49542
# 2017  -1.34973
# 2018       NaN

# %%
hedge_ratio_store
# Out:
#      hedge_ratio
# 1996     1.08318
# 1997     1.06945
# 1998     1.08213
# 1999     1.10801
# 2000     1.05684
# 2001     1.05196
# 2002     1.03435
# 2003     1.05994
# 2004      1.0788
# 2005     1.03557
# 2006     1.02023
# 2007    0.988892
# 2008      1.0028
# 2009     1.01015
# 2010     1.00813
# 2011    0.916594
# 2012    0.889657
# 2013    0.897159
# 2014    0.912915
# 2015      0.9123
# 2016    0.999655
# 2017    0.961555
# 2018         NaN

# %%
final_pnl_store
# Out:
#      final_pnl
# 1996      1410
# 1997       770
# 1998       380
# 1999       630
# 2000      1970
# 2001       960
# 2002      1730
# 2003       770
# 2004      3410
# 2005      3270
# 2006      1090
# 2007      -810
# 2008       700
# 2009       -50
# 2010      -190
# 2011     -1080
# 2012      2550
# 2013     -4320
# 2014      2770
# 2015      3180
# 2016        90
# 2017        70
# 2018       NaN

# %%
final_pnl_hr_store
# Out:
#      final_pnl_hr
# 1996      1468.23
# 1997      920.707
# 1998      303.623
# 1999      867.629
# 2000      2064.92
# 2001      990.655
# 2002      1763.32
# 2003      889.884
# 2004      3337.51
# 2005      3551.38
# 2006      1134.31
# 2007     -795.227
# 2008      704.511
# 2009     -74.5639
# 2010     -141.611
# 2011     -1007.44
# 2012      2673.58
# 2013      -4801.3
# 2014      2684.66
# 2015      2083.76
# 2016      90.0104
# 2017      272.607
# 2018          NaN

# %%
min_pnl_store
# Out:
#      min_pnl
# 1996       0
# 1997       0
# 1998     -10
# 1999    -190
# 2000       0
# 2001       0
# 2002     -60
# 2003      70
# 2004       0
# 2005    -180
# 2006       0
# 2007   -2180
# 2008    -790
# 2009   -1090
# 2010    -540
# 2011   -3260
# 2012   -3720
# 2013   -4930
# 2014       0
# 2015       0
# 2016    -600
# 2017    -340
# 2018     NaN

# %%
#print results

print 'The sum of final pnl across years w/o using hedge ratio is %.2f.' %final_pnl_store.sum()
win_percent=(final_pnl_store[final_pnl_store>=0].count()/final_pnl_store.count())*100
print 'The winning percentage of trades across years w/o using hedge ratio is %.2f percent.' %win_percent

print 'The sum of final pnl across years using hedge ratio is %.2f.' %final_pnl_hr_store.sum()
win_percent_hr=(final_pnl_hr_store[final_pnl_hr_store>=0].count()/final_pnl_hr_store.count())*100
print 'The winning percentage of trades across years using hedge ratio is %.2f percent.' %win_percent_hr
# Out:
# The sum of final pnl across years w/o using hedge ratio is 19300.00.
# The winning percentage of trades across years w/o using hedge ratio is 77.27 percent.
# The sum of final pnl across years using hedge ratio is 18981.15.
# The winning percentage of trades across years using hedge ratio is 77.27 percent.

# %%
min_pnl_store
# Out:
#      min_pnl
# 1996       0
# 1997       0
# 1998     -10
# 1999    -190
# 2000       0
# 2001       0
# 2002     -60
# 2003      70
# 2004       0
# 2005    -180
# 2006       0
# 2007   -2180
# 2008    -790
# 2009   -1090
# 2010    -540
# 2011   -3260
# 2012   -3720
# 2013   -4930
# 2014       0
# 2015       0
# 2016    -600
# 2017    -340
# 2018     NaN

# %%
temp
# Out:
#        Front_Month_Settle  Back_Month_Settle  Spread      MA     M_STD  \
# Date
# 01/03               55.95              57.66   -1.71     NaN       NaN
# 01/04               56.94              58.57   -1.63     NaN       NaN
# 01/05               57.30              58.86   -1.56     NaN       NaN
# 01/06               57.51              59.03   -1.52     NaN       NaN
# 01/09               55.83              57.08   -1.25     NaN       NaN
# 01/10               54.72              55.89   -1.17     NaN       NaN
# 01/11               55.99              57.02   -1.03     NaN       NaN
# 01/12               56.81              57.90   -1.09     NaN       NaN
# 01/13               56.08              57.28   -1.20     NaN       NaN
# 01/17               56.10              57.45   -1.35     NaN       NaN
# 01/18               54.74              56.03   -1.29     NaN       NaN
# 01/19               54.85              56.29   -1.44     NaN       NaN
# 01/20               55.89              57.53   -1.64     NaN       NaN
# 01/23               55.48              57.11   -1.63     NaN       NaN
# 01/24               55.67              57.29   -1.62     NaN       NaN
# 01/25               55.17              56.74   -1.57     NaN       NaN
# 01/26               56.00              57.58   -1.58     NaN       NaN
# 01/27               55.28              56.65   -1.37     NaN       NaN
# 01/30               54.93              56.41   -1.48     NaN       NaN
# 01/31               55.05              56.58   -1.53 -1.4330  0.202123
# 02/01               55.95              57.72   -1.77 -1.4360  0.206841
# 02/02               55.69              57.40   -1.71 -1.4400  0.211511
# 02/03               56.04              57.73   -1.69 -1.4465  0.217311
# 02/06               55.28              56.86   -1.58 -1.4495  0.218788
# 02/07               54.38              56.04   -1.66 -1.4700  0.218319
# 02/08               54.42              56.25   -1.83 -1.5030  0.220456
# 02/09               54.91              56.78   -1.87 -1.5450  0.205080
# 02/10               55.82              57.70   -1.88 -1.5845  0.188218
# 02/13               54.90              56.60   -1.70 -1.6095  0.166401
# 02/14               55.12              56.86   -1.74 -1.6290  0.156975
# ...                   ...                ...     ...     ...       ...
# 05/12               48.67              51.20   -2.53 -2.4920  0.078378
# 05/15               49.61              52.14   -2.53 -2.4945  0.078772
# 05/16               49.55              52.09   -2.54 -2.5050  0.069092
# 05/17               49.97              52.61   -2.64 -2.5220  0.056717
# 05/18               50.14              52.82   -2.68 -2.5350  0.061687
# 05/19               51.13              53.90   -2.77 -2.5475  0.080843
# 05/22               51.63              54.30   -2.67 -2.5535  0.085365
# 05/23               51.92              54.61   -2.69 -2.5555  0.088167
# 05/24               51.76              54.45   -2.69 -2.5640  0.092645
# 05/25               49.33              52.00   -2.67 -2.5700  0.095532
# 05/26               50.23              52.75   -2.52 -2.5700  0.095532
# 05/30               50.10              52.51   -2.41 -2.5675  0.099148
# 05/31               48.74              51.09   -2.35 -2.5605  0.109327
# 06/01               48.79              50.97   -2.18 -2.5410  0.138446
# 06/02               48.05              50.24   -2.19 -2.5255  0.159092
# 06/05               47.75              49.81   -2.06 -2.5015  0.189994
# 06/06               48.49              50.42   -1.93 -2.4720  0.228809
# 06/07               46.22              48.43   -2.21 -2.4595  0.236209
# 06/08               46.13              48.26   -2.13 -2.4425  0.247384
# 06/09               46.32              48.53   -2.21 -2.4300  0.252712
# 06/12               46.56              48.64   -2.08 -2.4075  0.263156
# 06/13               46.89              49.05   -2.16 -2.3890  0.267068
# 06/14               45.14              47.29   -2.15 -2.3695  0.269687
# 06/15               44.91              47.19   -2.28 -2.3515  0.262604
# 06/16               45.20              47.63   -2.43 -2.3390  0.251875
# 06/19               44.69              47.13   -2.44 -2.3225  0.232195
# 06/20               43.77              46.25   -2.48 -2.3130  0.220838
# 06/21               42.75              45.05   -2.30 -2.2935  0.202232
# 06/22               42.97              45.41   -2.44 -2.2810  0.183271
# 06/23               43.27              45.75   -2.48 -2.2715  0.166173
#
#         z_score  long_entry  long_exit  short_entry  short_exit  \
# Date
# 01/03       NaN         0.0        0.0          0.0         0.0
# 01/04       NaN         0.0        0.0          0.0         0.0
# 01/05       NaN         0.0        0.0          0.0         0.0
# 01/06       NaN         0.0        0.0          0.0         0.0
# 01/09       NaN         0.0        0.0          0.0         0.0
# 01/10       NaN         0.0        0.0          0.0         0.0
# 01/11       NaN         0.0        0.0          0.0         0.0
# 01/12       NaN         0.0        0.0          0.0         0.0
# 01/13       NaN         0.0        0.0          0.0         0.0
# 01/17       NaN         0.0        0.0          0.0         0.0
# 01/18       NaN         0.0        0.0          0.0         0.0
# 01/19       NaN         0.0        0.0          0.0         0.0
# 01/20       NaN         0.0        0.0          0.0         0.0
# 01/23       NaN         0.0        0.0          0.0         0.0
# 01/24       NaN         0.0        0.0          0.0         0.0
# 01/25       NaN         0.0        0.0          0.0         0.0
# 01/26       NaN         0.0        0.0          0.0         0.0
# 01/27       NaN         0.0        0.0          0.0         0.0
# 01/30       NaN         0.0        0.0          0.0         0.0
# 01/31 -0.479906         0.0       -1.0          0.0         1.0
# 02/01 -1.614768         0.0        0.0          0.0         1.0
# 02/02 -1.276530         0.0        0.0          0.0         1.0
# 02/03 -1.120515         0.0        0.0          0.0         1.0
# 02/06 -0.596468         0.0       -1.0          0.0         1.0
# 02/07 -0.870286         0.0       -1.0          0.0         1.0
# 02/08 -1.483286         0.0        0.0          0.0         1.0
# 02/09 -1.584746         0.0        0.0          0.0         1.0
# 02/10 -1.569987         0.0        0.0          0.0         1.0
# 02/13 -0.543868         0.0       -1.0          0.0         1.0
# 02/14 -0.707120         0.0       -1.0          0.0         1.0
# ...         ...         ...        ...          ...         ...
# 05/12 -0.484828         0.0       -1.0          0.0         1.0
# 05/15 -0.450669         0.0       -1.0          0.0         1.0
# 05/16 -0.506572         0.0       -1.0          0.0         1.0
# 05/17 -2.080497         0.0        0.0          0.0         1.0
# 05/18 -2.350583         2.0        0.0          0.0         1.0
# 05/19 -2.752262         2.0        0.0          0.0         1.0
# 05/22 -1.364735         0.0        0.0          0.0         1.0
# 05/23 -1.525514         0.0        0.0          0.0         1.0
# 05/24 -1.360025         0.0        0.0          0.0         1.0
# 05/25 -1.046772         0.0        0.0          0.0         1.0
# 05/26  0.523386         0.0       -1.0          0.0         1.0
# 05/30  1.588539         0.0       -1.0          0.0         0.0
# 05/31  1.925418         0.0       -1.0          0.0         0.0
# 06/01  2.607510         0.0       -1.0         -2.0         0.0
# 06/02  2.108843         0.0       -1.0         -2.0         0.0
# 06/05  2.323760         0.0       -1.0         -2.0         0.0
# 06/06  2.368785         0.0       -1.0         -2.0         0.0
# 06/07  1.056270         0.0       -1.0          0.0         0.0
# 06/08  1.263220         0.0       -1.0          0.0         0.0
# 06/09  0.870558         0.0       -1.0          0.0         1.0
# 06/12  1.244507         0.0       -1.0          0.0         0.0
# 06/13  0.857460         0.0       -1.0          0.0         1.0
# 06/14  0.813905         0.0       -1.0          0.0         1.0
# 06/15  0.272273         0.0       -1.0          0.0         1.0
# 06/16 -0.361290         0.0       -1.0          0.0         1.0
# 06/19 -0.506040         0.0       -1.0          0.0         1.0
# 06/20 -0.756210         0.0       -1.0          0.0         1.0
# 06/21 -0.032141         0.0       -1.0          0.0         1.0
# 06/22 -0.867566         0.0       -1.0          0.0         1.0
# 06/23 -1.254717         0.0        0.0          0.0         1.0
#
#        long_positions  short_positions  positions           pnl  cumpnl  \
# Date
# 01/03             NaN              NaN        NaN           NaN     NaN
# 01/04             NaN              NaN        NaN           NaN     NaN
# 01/05             NaN              NaN        NaN           NaN     NaN
# 01/06             NaN              NaN        NaN           NaN     NaN
# 01/09             NaN              NaN        NaN           NaN     NaN
# 01/10             NaN              NaN        NaN           NaN     NaN
# 01/11             NaN              NaN        NaN           NaN     NaN
# 01/12             NaN              NaN        NaN           NaN     NaN
# 01/13             NaN              NaN        NaN           NaN     NaN
# 01/17             NaN              NaN        NaN           NaN     NaN
# 01/18             NaN              NaN        NaN           NaN     NaN
# 01/19             NaN              NaN        NaN           NaN     NaN
# 01/20             NaN              NaN        NaN           NaN     NaN
# 01/23             NaN              NaN        NaN           NaN     NaN
# 01/24             NaN              NaN        NaN           NaN     NaN
# 01/25             NaN              NaN        NaN           NaN     NaN
# 01/26             NaN              NaN        NaN           NaN     NaN
# 01/27             NaN              NaN        NaN           NaN     NaN
# 01/30             NaN              NaN        NaN           NaN     NaN
# 01/31             0.0              0.0        0.0           NaN     NaN
# 02/01             0.0              0.0        0.0 -0.000000e+00     0.0
# 02/02             0.0              0.0        0.0  0.000000e+00     0.0
# 02/03             0.0              0.0        0.0  0.000000e+00     0.0
# 02/06             0.0              0.0        0.0  0.000000e+00     0.0
# 02/07             0.0              0.0        0.0 -0.000000e+00     0.0
# 02/08             0.0              0.0        0.0 -0.000000e+00     0.0
# 02/09             0.0              0.0        0.0 -0.000000e+00     0.0
# 02/10             0.0              0.0        0.0 -0.000000e+00     0.0
# 02/13             0.0              0.0        0.0  0.000000e+00     0.0
# 02/14             0.0              0.0        0.0 -0.000000e+00     0.0
# ...               ...              ...        ...           ...     ...
# 05/12             0.0              0.0        0.0 -0.000000e+00  -120.0
# 05/15             0.0              0.0        0.0  0.000000e+00  -120.0
# 05/16             0.0              0.0        0.0 -0.000000e+00  -120.0
# 05/17             0.0              0.0        0.0 -0.000000e+00  -120.0
# 05/18             1.0              0.0        1.0 -0.000000e+00  -120.0
# 05/19             1.0              0.0        1.0 -9.000000e+01  -210.0
# 05/22             1.0              0.0        1.0  1.000000e+02  -110.0
# 05/23             1.0              0.0        1.0 -2.000000e+01  -130.0
# 05/24             1.0              0.0        1.0 -7.105427e-12  -130.0
# 05/25             1.0              0.0        1.0  2.000000e+01  -110.0
# 05/26             0.0              0.0        0.0  1.500000e+02    40.0
# 05/30             0.0              0.0        0.0  0.000000e+00    40.0
# 05/31             0.0              0.0        0.0  0.000000e+00    40.0
# 06/01             0.0             -1.0       -1.0  0.000000e+00    40.0
# 06/02             0.0             -1.0       -1.0  1.000000e+01    50.0
# 06/05             0.0             -1.0       -1.0 -1.300000e+02   -80.0
# 06/06             0.0             -1.0       -1.0 -1.300000e+02  -210.0
# 06/07             0.0             -1.0       -1.0  2.800000e+02    70.0
# 06/08             0.0             -1.0       -1.0 -8.000000e+01   -10.0
# 06/09             0.0              0.0        0.0  8.000000e+01    70.0
# 06/12             0.0              0.0        0.0  0.000000e+00    70.0
# 06/13             0.0              0.0        0.0 -0.000000e+00    70.0
# 06/14             0.0              0.0        0.0  0.000000e+00    70.0
# 06/15             0.0              0.0        0.0 -0.000000e+00    70.0
# 06/16             0.0              0.0        0.0 -0.000000e+00    70.0
# 06/19             0.0              0.0        0.0 -0.000000e+00    70.0
# 06/20             0.0              0.0        0.0 -0.000000e+00    70.0
# 06/21             0.0              0.0        0.0  0.000000e+00    70.0
# 06/22             0.0              0.0        0.0 -0.000000e+00    70.0
# 06/23             0.0              0.0        0.0 -0.000000e+00    70.0
#
#        Spread_hr      pnl_hr   cumpnl_hr
# Date
# 01/03   0.506764         NaN         NaN
# 01/04   0.621749         NaN         NaN
# 01/05   0.702898         NaN         NaN
# 01/06   0.749434         NaN         NaN
# 01/09   0.944465         NaN         NaN
# 01/10   0.978715         NaN         NaN
# 01/11   1.162158         NaN         NaN
# 01/12   1.135990         NaN         NaN
# 01/13   1.002154         NaN         NaN
# 01/17   0.858690         NaN         NaN
# 01/18   0.864098         NaN         NaN
# 01/19   0.724093         NaN         NaN
# 01/20   0.571766         NaN         NaN
# 01/23   0.565619         NaN         NaN
# 01/24   0.582539         NaN         NaN
# 01/25   0.611394         NaN         NaN
# 01/26   0.633688         NaN         NaN
# 01/27   0.807934         NaN         NaN
# 01/30   0.688707         NaN         NaN
# 01/31   0.645243         NaN         NaN
# 02/01   0.449070   -0.000000    0.000000
# 02/02   0.496768    0.000000    0.000000
# 02/03   0.529455    0.000000    0.000000
# 02/06   0.606007    0.000000    0.000000
# 02/07   0.494482   -0.000000    0.000000
# 02/08   0.332556   -0.000000    0.000000
# 02/09   0.312932   -0.000000    0.000000
# 02/10   0.338301    0.000000    0.000000
# 02/13   0.476011    0.000000    0.000000
# 02/14   0.446007   -0.000000    0.000000
# ...          ...         ...         ...
# 05/12  -0.561594   -0.000000   -8.508249
# 05/15  -0.525455    0.000000   -8.508249
# 05/16  -0.537377   -0.000000   -8.508249
# 05/17  -0.617386   -0.000000   -8.508249
# 05/18  -0.649312   -0.000000   -8.508249
# 05/19  -0.697791  -48.478934  -56.987183
# 05/22  -0.582413  115.378173   58.390989
# 05/23  -0.590495   -8.081916   50.309073
# 05/24  -0.596646   -6.151269   44.157804
# 05/25  -0.670838  -74.191307  -30.033503
# 05/26  -0.492003  178.834074  148.800571
# 05/30  -0.391230    0.000000  148.800571
# 05/31  -0.385823    0.000000  148.800571
# 06/01  -0.220436    0.000000  148.800571
# 06/02  -0.258502   38.065165  186.865736
# 06/05  -0.145033 -113.468465   73.397271
# 06/06   0.008419 -153.451713  -80.054442
# 06/07  -0.348088  356.506408  276.451966
# 06/08  -0.274623  -73.464277  202.987690
# 06/09  -0.344243   69.619734  272.607423
# 06/12  -0.210014    0.000000  272.607423
# 06/13  -0.274252   -0.000000  272.607423
# 06/14  -0.331916   -0.000000  272.607423
# 06/15  -0.465760   -0.000000  272.607423
# 06/16  -0.598844   -0.000000  272.607423
# 06/19  -0.628067   -0.000000  272.607423
# 06/20  -0.701899   -0.000000  272.607423
# 06/21  -0.568033    0.000000  272.607423
# 06/22  -0.694193   -0.000000  272.607423
# 06/23  -0.721122   -0.000000  272.607423
#
# [120 rows x 18 columns]
